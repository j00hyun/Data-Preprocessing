# %%
import numpy as np
import pandas as pd

# %%
df_15 = pd.read_csv('dataset/avg15.09.csv')
df_15
# Out:
#    □ 평균 분양가격 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1         구분        NaN      2013년      2014년        NaN        NaN
# 2         시도        시군구        12월         1월         2월         3월
# 3         전국        NaN      8,059      8,130      8,195      8,204
# 4         서울        NaN     18,189     17,925     17,925     18,016
# 5      6대광역시         부산      8,111      8,111      9,078      8,965
# 6        NaN         대구      8,080      8,080      8,077      8,101
# 7        NaN         인천     10,204     10,204     10,408     10,408
# 8        NaN         광주      6,098      7,326      7,611      7,346
# 9        NaN         대전      8,321      8,321      8,321      8,341
# 10       NaN         울산      8,090      8,090      8,090      8,153
# 11       NaN        NaN      8,151      8,355      8,597      8,552
# 12        경기        NaN     10,855     10,855     10,791     10,784
# ...

# %%
df_18 = pd.read_csv('dataset/avg18.07.csv')
df_18
# Out:
#      지역명               규모구분    연도   월 분양가격(㎡)
# 0     서울                 전체  2015  10    5841
# 1     서울         전용면적 60㎡이하  2015  10    5652
# 2     서울   전용면적 60㎡초과 85㎡이하  2015  10    5882
# 3     서울  전용면적 85㎡초과 102㎡이하  2015  10    5721
# 4     서울        전용면적 102㎡초과  2015  10    5879
# ...   ..                ...   ...  ..     ...
# 2885  제주                 전체  2018   7    3334
# 2886  제주         전용면적 60㎡이하  2018   7     NaN
# 2887  제주   전용면적 60㎡초과 85㎡이하  2018   7    3356
# 2888  제주  전용면적 85㎡초과 102㎡이하  2018   7    3226
# 2889  제주        전용면적 102㎡초과  2018   7    2990
#
# [2890 rows x 5 columns]

# %%
df_15 = df_15.drop([df_15.columns[24],df_15.columns[25],df_15.columns[26]], axis = 1)
df_15
# Out:
#    □ 평균 분양가격 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1         구분        NaN      2013년      2014년        NaN        NaN
# 2         시도        시군구        12월         1월         2월         3월
# 3         전국        NaN      8,059      8,130      8,195      8,204
# 4         서울        NaN     18,189     17,925     17,925     18,016
# 5      6대광역시         부산      8,111      8,111      9,078      8,965
# 6        NaN         대구      8,080      8,080      8,077      8,101
# 7        NaN         인천     10,204     10,204     10,408     10,408
# 8        NaN         광주      6,098      7,326      7,611      7,346
# 9        NaN         대전      8,321      8,321      8,321      8,341
# 10       NaN         울산      8,090      8,090      8,090      8,153
# 11       NaN        NaN      8,151      8,355      8,597      8,552
# 12        경기        NaN     10,855     10,855     10,791     10,784
# ...

# %%
#구분/시/도 지움
df_15.iloc[3,1]=df_15.iloc[3,0]
df_15.iloc[4,1]=df_15.iloc[4,0]
df_15.iloc[12,1]=df_15.iloc[12,0]
df_15.iloc[14,1]=df_15.iloc[14,0]
df_15
# Out:
#    □ 평균 분양가격 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1         구분        NaN      2013년      2014년        NaN        NaN
# 2         시도        시군구        12월         1월         2월         3월
# 3         전국         전국      8,059      8,130      8,195      8,204
# 4         서울         서울     18,189     17,925     17,925     18,016
# 5      6대광역시         부산      8,111      8,111      9,078      8,965
# 6        NaN         대구      8,080      8,080      8,077      8,101
# 7        NaN         인천     10,204     10,204     10,408     10,408
# 8        NaN         광주      6,098      7,326      7,611      7,346
# 9        NaN         대전      8,321      8,321      8,321      8,341
# 10       NaN         울산      8,090      8,090      8,090      8,153
# 11       NaN        NaN      8,151      8,355      8,597      8,552
# 12        경기         경기     10,855     10,855     10,791     10,784
# ...

# %%
#연도 추가
for i in range(4,15):
    df_15.iloc[1,i] = df_15.iloc[1,3]
df_15
# Out:
#    □ 평균 분양가격 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1         구분        NaN      2013년      2014년      2014년      2014년
# 2         시도        시군구        12월         1월         2월         3월
# 3         전국         전국      8,059      8,130      8,195      8,204
# 4         서울         서울     18,189     17,925     17,925     18,016
# 5      6대광역시         부산      8,111      8,111      9,078      8,965
# 6        NaN         대구      8,080      8,080      8,077      8,101
# 7        NaN         인천     10,204     10,204     10,408     10,408
# 8        NaN         광주      6,098      7,326      7,611      7,346
# 9        NaN         대전      8,321      8,321      8,321      8,341
# 10       NaN         울산      8,090      8,090      8,090      8,153
# 11       NaN        NaN      8,151      8,355      8,597      8,552
# 12        경기         경기     10,855     10,855     10,791     10,784
# ...

# %%
#연도 추가
for i in range(16,24):
    df_15.iloc[1,i] = df_15.iloc[1,15]
df_15
# Out:
#    □ 평균 분양가격 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1         구분        NaN      2013년      2014년      2014년      2014년
# 2         시도        시군구        12월         1월         2월         3월
# 3         전국         전국      8,059      8,130      8,195      8,204
# 4         서울         서울     18,189     17,925     17,925     18,016
# 5      6대광역시         부산      8,111      8,111      9,078      8,965
# 6        NaN         대구      8,080      8,080      8,077      8,101
# 7        NaN         인천     10,204     10,204     10,408     10,408
# 8        NaN         광주      6,098      7,326      7,611      7,346
# 9        NaN         대전      8,321      8,321      8,321      8,341
# 10       NaN         울산      8,090      8,090      8,090      8,153
# 11       NaN        NaN      8,151      8,355      8,597      8,552
# 12        경기         경기     10,855     10,855     10,791     10,784
# ...

# %%
#수도권/6대 광역시 평균 삭제
df_15 = df_15.drop(df_15.index[13])
df_15 = df_15.drop(df_15.index[11])

df_15
# Out:
#    □ 평균 분양가격 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1         구분        NaN      2013년      2014년      2014년      2014년
# 2         시도        시군구        12월         1월         2월         3월
# 3         전국         전국      8,059      8,130      8,195      8,204
# 4         서울         서울     18,189     17,925     17,925     18,016
# 5      6대광역시         부산      8,111      8,111      9,078      8,965
# 6        NaN         대구      8,080      8,080      8,077      8,101
# 7        NaN         인천     10,204     10,204     10,408     10,408
# 8        NaN         광주      6,098      7,326      7,611      7,346
# 9        NaN         대전      8,321      8,321      8,321      8,341
# 10       NaN         울산      8,090      8,090      8,090      8,153
# 12        경기         경기     10,855     10,855     10,791     10,784
# 14        세종         세종      7,601      7,600      7,532      7,814
# ...

# %%
#지방평균 삭제
df_15 = df_15.drop(df_15.index[21])
df_15
# Out:
#    □ 평균 분양가격 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1         구분        NaN      2013년      2014년      2014년      2014년
# 2         시도        시군구        12월         1월         2월         3월
# 3         전국         전국      8,059      8,130      8,195      8,204
# 4         서울         서울     18,189     17,925     17,925     18,016
# 5      6대광역시         부산      8,111      8,111      9,078      8,965
# 6        NaN         대구      8,080      8,080      8,077      8,101
# 7        NaN         인천     10,204     10,204     10,408     10,408
# 8        NaN         광주      6,098      7,326      7,611      7,346
# 9        NaN         대전      8,321      8,321      8,321      8,341
# 10       NaN         울산      8,090      8,090      8,090      8,153
# 12        경기         경기     10,855     10,855     10,791     10,784
# 14        세종         세종      7,601      7,600      7,532      7,814
# ...

# %%
# row[0] Nan 있는 줄 삭제
df_15 = df_15.drop(df_15.index[0])
df_15
# Out:
#    □ 평균 분양가격 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 1         구분        NaN      2013년      2014년      2014년      2014년
# 2         시도        시군구        12월         1월         2월         3월
# 3         전국         전국      8,059      8,130      8,195      8,204
# 4         서울         서울     18,189     17,925     17,925     18,016
# 5      6대광역시         부산      8,111      8,111      9,078      8,965
# 6        NaN         대구      8,080      8,080      8,077      8,101
# 7        NaN         인천     10,204     10,204     10,408     10,408
# 8        NaN         광주      6,098      7,326      7,611      7,346
# 9        NaN         대전      8,321      8,321      8,321      8,341
# 10       NaN         울산      8,090      8,090      8,090      8,153
# 12        경기         경기     10,855     10,855     10,791     10,784
# 14        세종         세종      7,601      7,600      7,532      7,814
# 15        지방         강원      6,230      6,230      6,230      6,141
# ...

# %%
#평균분양가격 column 삭제 
df_15 = df_15.drop(df_15.columns[0], axis = 1)
df_15 = df_15.reset_index()
df_15 = df_15.drop(['index'], axis =1 )
df_15
# Out:
#    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0         NaN      2013년      2014년      2014년      2014년      2014년
# 1         시군구        12월         1월         2월         3월         4월
# 2          전국      8,059      8,130      8,195      8,204      8,289
# 3          서울     18,189     17,925     17,925     18,016     18,098
# 4          부산      8,111      8,111      9,078      8,965      9,402
# 5          대구      8,080      8,080      8,077      8,101      8,267
# 6          인천     10,204     10,204     10,408     10,408     10,000
# 7          광주      6,098      7,326      7,611      7,346      7,346
# 8          대전      8,321      8,321      8,321      8,341      8,341
# 9          울산      8,090      8,090      8,090      8,153      8,153
# 10         경기     10,855     10,855     10,791     10,784     10,876
# 11         세종      7,601      7,600      7,532      7,814      7,908
# 12         강원      6,230      6,230      6,230      6,141      6,373
# ...

# %%
# 저장을 위해 utf-8로 인코딩 이거 필수적인 작업 다들 참고 하세요
df_15.to_csv('dataset/avg15_new.csv',encoding = 'utf-8')

# %%
df_18 = pd.read_csv('dataset/avg18.07.csv')
df_18 = df_18.loc[df_18['규모구분'] == '전체']
df_18 = df_18.drop(['규모구분'], axis =1)

df_18
# Out:
#      지역명    연도   월 분양가격(㎡)
# 0     서울  2015  10    5841
# 5     인천  2015  10    3163
# 10    경기  2015  10    3138
# 15    부산  2015  10    3112
# 20    대구  2015  10    2682
# ...   ..   ...  ..     ...
# 2865  전북  2018   7    2333
# 2870  전남  2018   7    2357
# 2875  경북  2018   7    2674
# 2880  경남  2018   7    2696
# 2885  제주  2018   7    3334
#
# [578 rows x 4 columns]

# %%
df_18.to_csv('dataset/avg18_new.csv',encoding = 'utf-8')

# %%
#필요 없는 row 삭제
df_15_sub = df_15.drop(0)
df_15_sub = df_15_sub.drop(1)
df_15_sub = df_15_sub.drop(2)
df_15_sub
# Out:
#    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 3          서울     18,189     17,925     17,925     18,016     18,098
# 4          부산      8,111      8,111      9,078      8,965      9,402
# 5          대구      8,080      8,080      8,077      8,101      8,267
# 6          인천     10,204     10,204     10,408     10,408     10,000
# 7          광주      6,098      7,326      7,611      7,346      7,346
# 8          대전      8,321      8,321      8,321      8,341      8,341
# 9          울산      8,090      8,090      8,090      8,153      8,153
# 10         경기     10,855     10,855     10,791     10,784     10,876
# 11         세종      7,601      7,600      7,532      7,814      7,908
# 12         강원      6,230      6,230      6,230      6,141      6,373
# 13         충북      6,589      6,589      6,611      6,625      6,678
# 14         충남      6,365      6,365      6,379      6,287      6,552
# 15         전북      6,282      6,281      5,946      5,966      6,277
# ...

# %%
df_15_sub
# Out:
#    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 3          서울     18,189     17,925     17,925     18,016     18,098
# 4          부산      8,111      8,111      9,078      8,965      9,402
# 5          대구      8,080      8,080      8,077      8,101      8,267
# 6          인천     10,204     10,204     10,408     10,408     10,000
# 7          광주      6,098      7,326      7,611      7,346      7,346
# 8          대전      8,321      8,321      8,321      8,341      8,341
# 9          울산      8,090      8,090      8,090      8,153      8,153
# 10         경기     10,855     10,855     10,791     10,784     10,876
# 11         세종      7,601      7,600      7,532      7,814      7,908
# 12         강원      6,230      6,230      6,230      6,141      6,373
# 13         충북      6,589      6,589      6,611      6,625      6,678
# 14         충남      6,365      6,365      6,379      6,287      6,552
# 15         전북      6,282      6,281      5,946      5,966      6,277
# ...

# %%
#18년도 형태로 데이터 수정
df_15_sub.rename(columns = lambda x: '지역명' if x == 'Unnamed: 1' else '분양가격(㎡)', inplace = True)
df_con = []
for i in range(1,23) :
    df_con.append(df_15_sub.iloc[:,[0,i]])
df_con
# Out:
# [   지역명 분양가격(㎡)
#  3   서울  18,189
#  4   부산   8,111
#  5   대구   8,080
#  6   인천  10,204
#  7   광주   6,098
#  8   대전   8,321
#  9   울산   8,090
#  10  경기  10,855
#  11  세종   7,601
#  12  강원   6,230
#  13  충북   6,589
#  14  충남   6,365
#  15  전북   6,282
#  16  전남   5,678
#  17  경북   6,168
#  18  경남   6,473
#  19  제주   7,674,
#     지역명 분양가격(㎡)
#  3   서울  17,925
#  4   부산   8,111
#  5   대구   8,080
#  6   인천  10,204
#  7   광주   7,326
#  8   대전   8,321
#  9   울산   8,090
#  10  경기  10,855
#  11  세종   7,600
#  12  강원   6,230
#  13  충북   6,589
#  14  충남   6,365
#  15  전북   6,281
#  16  전남   5,678
#  17  경북   6,168
#  18  경남   6,485
#  19  제주   7,900,
#     지역명 분양가격(㎡)
#  3   서울  17,925
#  4   부산   9,078
#  5   대구   8,077
#  6   인천  10,408
#  7   광주   7,611
#  8   대전   8,321
#  9   울산   8,090
#  10  경기  10,791
#  11  세종   7,532
#  12  강원   6,230
#  13  충북   6,611
#  14  충남   6,379
#  15  전북   5,946
#  16  전남   5,678
#  17  경북   6,234
#  18  경남   6,502
#  19  제주   7,900,
#     지역명 분양가격(㎡)
# ...

# %%
# 15년 데이터에 컬럼 추가 및 분양가격 수정
index = 1
for i in df_con :
    i['연도'] = df_15.iloc[0,index].replace('년','')
    i['월'] = df_15.iloc[1,index].replace('월','')
    i['분양가격(㎡)']= (i['분양가격(㎡)'].str.replace(',','').astype('float64')/3.3).astype('int64').astype('str')
    index = index + 1
df_con
# Out:
# /Users/parkjoohyun/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/parkjoohyun/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/parkjoohyun/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df_con.append(df_18_new)
df_con
# Out:
# [   지역명 분양가격(㎡)    연도   월
#  3   서울    5511  2013  12
#  4   부산    2457  2013  12
#  5   대구    2448  2013  12
#  6   인천    3092  2013  12
#  7   광주    1847  2013  12
#  8   대전    2521  2013  12
#  9   울산    2451  2013  12
#  10  경기    3289  2013  12
#  11  세종    2303  2013  12
#  12  강원    1887  2013  12
#  13  충북    1996  2013  12
#  14  충남    1928  2013  12
#  15  전북    1903  2013  12
#  16  전남    1720  2013  12
#  17  경북    1869  2013  12
#  18  경남    1961  2013  12
#  19  제주    2325  2013  12,
#     지역명 분양가격(㎡)    연도  월
#  3   서울    5431  2014  1
#  4   부산    2457  2014  1
#  5   대구    2448  2014  1
#  6   인천    3092  2014  1
#  7   광주    2220  2014  1
#  8   대전    2521  2014  1
#  9   울산    2451  2014  1
#  10  경기    3289  2014  1
#  11  세종    2303  2014  1
#  12  강원    1887  2014  1
#  13  충북    1996  2014  1
#  14  충남    1928  2014  1
#  15  전북    1903  2014  1
#  16  전남    1720  2014  1
#  17  경북    1869  2014  1
#  18  경남    1965  2014  1
#  19  제주    2393  2014  1,
# ...

# %%
# 리스트 형태를 DataFrame 형태로 수정
df1 = pd.concat(df_con)
df1
# Out:
#      지역명 분양가격(㎡)    연도   월               규모구분
# 3     서울    5511  2013  12                NaN
# 4     부산    2457  2013  12                NaN
# 5     대구    2448  2013  12                NaN
# 6     인천    3092  2013  12                NaN
# 7     광주    1847  2013  12                NaN
# ...   ..     ...   ...  ..                ...
# 2885  제주    3334  2018   7                 전체
# 2886  제주     NaN  2018   7         전용면적 60㎡이하
# 2887  제주    3356  2018   7   전용면적 60㎡초과 85㎡이하
# 2888  제주    3226  2018   7  전용면적 85㎡초과 102㎡이하
# 2889  제주    2990  2018   7        전용면적 102㎡초과
#
# [3264 rows x 5 columns]

# %%
# 필요없는 데이터 삭제
del df1['Unnamed: 0']
df1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Unnamed: 0'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-94-2dd3656b04e3> in <module>
#       1 # 필요없는 데이터 삭제
# ...

# %%
df1

# %%
df1.to_csv('0.dataset/total_avg.csv', encoding = 'utf-8')

# %%
df1.loc[df1['지역명']=='전남']
